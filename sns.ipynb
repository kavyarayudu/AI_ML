# %% [markdown]
# <a href="https://colab.research.google.com/github/kavyarayudu/AI_ML/blob/master/sns.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/sample_data/california_housing_test.csv")
print(df)
# Out:
#       longitude  latitude  ...  median_income  median_house_value
# 0       -122.05     37.37  ...         6.6085            344700.0
# 1       -118.30     34.26  ...         3.5990            176500.0
# 2       -117.81     33.78  ...         5.7934            270500.0
# 3       -118.36     33.82  ...         6.1359            330000.0
# 4       -119.67     36.33  ...         2.9375             81700.0
# ...         ...       ...  ...            ...                 ...
# 2995    -119.86     34.42  ...         1.1790            225000.0
# 2996    -118.14     34.06  ...         3.3906            237200.0
# 2997    -119.70     36.30  ...         2.2895             62000.0
# 2998    -117.12     34.10  ...         3.2708            162500.0
# 2999    -119.63     34.42  ...         8.5608            500001.0
#
# [3000 rows x 9 columns]

# %%
print(df.columns)
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
# longitude             3000 non-null float64
# latitude              3000 non-null float64
# housing_median_age    3000 non-null float64
# total_rooms           3000 non-null float64
# total_bedrooms        3000 non-null float64
# population            3000 non-null float64
# households            3000 non-null float64
# median_income         3000 non-null float64
# median_house_value    3000 non-null float64
# dtypes: float64(9)
# memory usage: 211.1 KB
# None

# %%
print(df.dtypes)
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
sns.boxplot(y=df["households"])

# %%
sns.boxplot(y=df["median_house_value"])

# %%
import pandas as pd
cars_df=pd.read_csv("/content/toyotacorollacsv.zip")
print(cars_df)
# Out:
#         Id  ... Tow_Bar
# 0        1  ...       0
# 1        2  ...       0
# 2        3  ...       0
# 3        4  ...       0
# 4        5  ...       0
# ...    ...  ...     ...
# 1431  1438  ...       0
# 1432  1439  ...       0
# 1433  1440  ...       0
# 1434  1441  ...       0
# 1435  1442  ...       0
#
# [1436 rows x 37 columns]

# %%
print(cars_df.columns)
# Out:
# Index(['Id', 'Model', 'Price', 'Age_08_04', 'Mfg_Month', 'Mfg_Year', 'KM',
#        'Fuel_Type', 'HP', 'Met_Color', 'Automatic', 'cc', 'Doors', 'Cylinders',
#        'Gears', 'Quarterly_Tax', 'Weight', 'Mfr_Guarantee', 'BOVAG_Guarantee',
#        'Guarantee_Period', 'ABS', 'Airbag_1', 'Airbag_2', 'Airco',
#        'Automatic_airco', 'Boardcomputer', 'CD_Player', 'Central_Lock',
#        'Powered_Windows', 'Power_Steering', 'Radio', 'Mistlamps',
#        'Sport_Model', 'Backseat_Divider', 'Metallic_Rim', 'Radio_cassette',
#        'Tow_Bar'],
#       dtype='object')

# %%
sns.boxplot(x=cars_df['Fuel_Type'],y = cars_df['Price'])

# %%
sns.boxplot(x =cars_df[ "Fuel_Type"],y = cars_df["Price"],hue= "Radio",data = cars_df)

# %%
sns.boxplot(x=cars_df["Fuel_Type"],y=cars_df["KM"])

# %%
sns.boxplot(x=cars_df["Fuel_Type"],y=cars_df["Met_Color"],hue="Airco",data=cars_df)

# %%
import seaborn as sns
sns.pairplot(cars_df,hue="Fuel_Type",kind="scatter")
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# ...

# %%
import seaborn as sns
sns.set(style="dark")
tips=sns.load_dataset("tips")
print(tips.columns)
print(tips.head)
sns.boxplot(x=tips["size"])
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')
# <bound method NDFrame.head of      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]>

# %%
import seaborn as sns
sns.set(style="ticks")
tips=sns.load_dataset("tips")
sns.stripplot(x=tips["total_bill"])

# %%
ax=sns.boxplot(x="day",y="total_bill",data=tips)

# %%
sns.boxplot(x="day", y="total_bill", hue="smoker",
                 data=tips, palette="husl")

# %%
sns.boxplot(x="day", y="total_bill", hue="smoker",
                 data=tips, palette="GnBu",linewidth=1.5)

# %%
import seaborn as sns
iris=sns.load_dataset("iris")
ax = sns.boxplot(data=iris, orient="h", palette="Set3")

# %%
sns.boxplot(x="time",y="tip",data=tips,
            order=["Dinner","Lunch"])

# %%
sns.boxplot(x="day",y="total_bill",data=tips,color="blue")
sns.swarmplot(x="day",y="total_bill",data=tips,color="pink")

# %%
import seaborn as sns
sns.set(style='whitegrid')
tips=sns.load_dataset("tips")
sns.violinplot(x=tips["total_bill"])

# %%
import seaborn as sns
sns.violinplot(x="total_bill",y="day",data=tips)

# %%
sns.violinplot(x="day", y="total_bill", hue="smoker",
                    data=tips, palette="muted")

# %%
sns.violinplot(x="day", y="total_bill", hue="smoker",
                    data=tips, palette="muted", split=False)

# %%
sns.violinplot(x="time",y="tip",data=tips,
               order=["Dinner","Lunch"])

# %%
import seaborn as sns
sns.set(style="whitegrid")
tips=sns.load_dataset("tips")
sns.stripplot(x=tips["total_bill"])

# %%
sns.stripplot(x="day",y="total_bill",data=tips)

# %%
sns.stripplot(x="day",y="total_bill",data=tips,jitter=0.25)

# %%
sns.stripplot(x="total_bill", y="day", data=tips)

# %%
sns.stripplot(x="sex",y="total_bill",hue="day",data=tips)

# %%
import seaborn as sns
sns.set(style="dark")
tips = sns.load_dataset("tips")
ax = sns.swarmplot(x=tips["total_bill"])

# %%
sns.swarmplot(x="day",y="total_bill",data=tips,palette="husl")

# %%
sns.swarmplot(x="total_bill",y="day",data=tips,palette="cubehelix")

# %%
sns.swarmplot(x="day",y="total_bill",hue="sex",data=tips,palette="husl")

# %%
sns.swarmplot(x="time", y="tip", data=tips,
                   order=["Dinner", "Lunch"],size=10)

# %%
sns.boxplot(x="tip", y="day", data=tips,palette='BuGn')
sns.swarmplot(x="tip", y="day", data=tips, color=".2")

# %%
sns.violinplot(x="day", y="total_bill", data=tips, inner=None,palette="Blues")
sns.swarmplot(x="day", y="total_bill", data=tips,
                   palette="GnBu")
